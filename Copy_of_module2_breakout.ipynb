# %% [markdown]
# <a href="https://colab.research.google.com/github/SIT-COMP-1210/module2-breakout-RibkaBegashaw/blob/main/Copy_of_module2_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SIT-COMP-1210/Module2-Breakout-{RibkaBegashaw}.git
# Out:
# Cloning into 'Module2-Breakout-yturura'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 5.10 KiB | 2.55 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %% [markdown]
# **Data Types and Arithmetic Operators Exercise**

# %% [markdown]
# 1. What is the type of 2?

# %%
'''
your code here
'''
type(2)
# Out:
# int

# %% [markdown]
# 2. What is the type of 2.0?

# %%
'''
your code here
'''
type(2.0)
# Out:
# float

# %% [markdown]
# 3. What is the resulting type of adding 2 and 2?

# %%
'''
your code here
'''
type(2+2)
print(2+2)
# Out:
# 4

# %% [markdown]
# 4. What is the type of ‘Programming’ ?

# %%
'''
your code here
'''
type('Programming')
# Out:
# str

# %% [markdown]
# 5. What is the resulting output when you add ‘Programming’ and ‘Computer’?

# %%
'''
your code here
'''
print('Programming' + 'Computer')
# Out:
# ProgrammingComputer

# %% [markdown]
# 6. What is the result of ‘Ethiopia’ * 3 ?

# %%
'''
your code here
'''
print('Ethiopia'*3)
type("Ethiopia" *3)
# Out:
# EthiopiaEthiopiaEthiopia
# str

# %% [markdown]
# 7. What is the result of 10.0 * 7?

# %%
'''
your code here
'''
type(10.0*7)
print(10.0*7)
# Out:
# 70.0

# %% [markdown]
# 8. What is stored in result?

# %%
result =(str(int(2.8)))
print(result)
type(result)
# Out:
# 2
# str

# %% [markdown]
# 9. What is the final value and type of x?

# %%
x = int(float(-5))
print(x)
type(x)
int(2.8)
# Out:
# -5
# 2

# %% [markdown]
# 10. What is stored in expr? What is the order of operations?

# %%
expr = "a" + "b" * 2 + "c"
print(expr)
type(expr)
# Out:
# abbc
# str

# %% [markdown]
# 11. What is the final value of value?

# %%
value = 100 / 5 // 4 * 3 % 5
print(value)
type(value)
# Out:
# 0.0
# float

# %% [markdown]
# 12. hat is the value of b? Why does this happen?

# %%
b = bool(0)
print(b)
type(b)
# Out:
# False
# bool

# %% [markdown]
# 13. Why are the results numerically the same but types different?

# %%
a = 4 * 3
b = 4 * 3.0
print(a)
type(a)
print(b)
type(b)
# Out:
# 12
# 12.0
# float

# %% [markdown]
# 14. Does calling int() on an int or float() on a float change the value? Why or why not?

# %%
x = int(5)
type(x)
print(x)
y = float(5.0)
print(y)
type(y)
# Out:
# 5
# 5.0
# float

# %% [markdown]
# 15. What is the value and type of x?

# %%
x = 2 ** 3
print(x)
type(x)
# Out:
# 8
# int

# %% [markdown]
# 16. What is the value of y?

# %%
y = 4 * 2 ** 2
print(y)
# Out:
# 16

# %% [markdown]
# 17. What is the value of a?

# %%
a = 5 - 1 + 4 * 2
print(a)
# Out:
# 12

# %% [markdown]
# 18. What is the value of b?

# %%
b = (5 - 1 + 4) * 2
print(b)
# Out:
# 16

# %% [markdown]
# 19. What are the values of b1 and b2? Are they the same? If not, why are they different?

# %%
b1 = bool("")
print(b1)
b2 = bool("False")
print(b2)
# Out:
# False
# True

# %% [markdown]
# 20. Is (2 + 3) * 4 an expression or a function?

# %%
# your answer here an expression

# %% [markdown]
# 21. What is the final value of result?

# %%
result = str(int(5.9) + 2 ** 2) * 2
print(result)
type(result)
# Out:
# 99
# str
